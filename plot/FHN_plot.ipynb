# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
import scipy.special as sci
np.random.seed(1234)
tf.set_random_seed(1234)
import matplotlib.pyplot as plt
import os
import pickle
# Out:
# E:\anan\envs\Tensorflow-37\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# E:\anan\envs\Tensorflow-37\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# E:\anan\envs\Tensorflow-37\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# # MET_inverse_para_k

# %% [markdown]
# # k=0.01decay

# %%
para1_history001=np.loadtxt(r"D:\new\code\2D\metinverse\0.01\decay\param_record_30w_10_5e-3_decay1000-420-100.txt")
para2_history001=np.loadtxt(r"D:\new\code\2D\metinverse\0.01\decay\param_record_30w_20_5e-3_decay1000-420-100.txt")
para3_history001=np.loadtxt(r"D:\new\code\2D\metinverse\0.01\decay\param_record_30w_30_5e-3_decay1000-420-100.txt")
para4_history001=np.loadtxt(r"D:\new\code\2D\metinverse\0.01\decay\param_record_30w_50_5e-3_decay1000-420-100.txt")

iterations = list(range(0, len(para1_history001) * 1000, 1000))
plt.figure(figsize=(6, 5))
plt.plot(iterations, para1_history001, label='ob_num=10', color='orange')
plt.plot(iterations, para2_history001, label='ob_num=20', color='b')
plt.plot(iterations, para3_history001, label='ob_num=30', color='y')
plt.plot(iterations, para4_history001, label='ob_num=50', color='purple')
plt.axhline(y=0.01, color='r', linestyle='--', label='True k = 0.01')  
max_iterations = max(iterations)

plt.xticks([i for i in range(0, max_iterations + 1, 50000)], 
           [str(i // 10000) for i in range(0, max_iterations + 1, 50000)])

plt.xlabel('Iteration (x10,000)',fontsize=14)
plt.ylabel('k Value',fontsize=14)
plt.legend(frameon=False,fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)

# %% [markdown]
# # k=0.01nondecay

# %%
##lr=5e-4
para1_history001_54=np.loadtxt(r"D:\new\code\2D\slum\metinverse\0.01\nondecay\param_record_30w_10_5e-4_nondecay-420-100.txt")
para2_history001_54=np.loadtxt(r"D:\new\code\2D\slum\metinverse\0.01\nondecay\param_record_30w_20_5e-4_nondecay-420-100.txt")
para3_history001_54=np.loadtxt(r"D:\new\code\2D\slum\metinverse\0.01\nondecay\param_record_30w_30_5e-4_nondecay-420-100.txt")
para4_history001_54=np.loadtxt(r"D:\new\code\2D\slum\metinverse\0.01\nondecay\param_record_30w_50_5e-4_nondecay-420-100.txt")

iterations = list(range(0, len(para1_history001_54) * 1000, 1000))
plt.figure(figsize=(6, 5))
plt.plot(iterations, para1_history001_54, label='ob_num=10', color='orange')
plt.plot(iterations, para2_history001_54, label='ob_num=20', color='b')
plt.plot(iterations, para3_history001_54, label='ob_num=30', color='y')
plt.plot(iterations, para4_history001_54, label='ob_num=50', color='purple')
plt.axhline(y=0.01, color='r', linestyle='--', label='True k = 0.01') 
max_iterations = max(iterations)

plt.xticks([i for i in range(0, max_iterations + 1, 50000)], 
           [str(i // 10000) for i in range(0, max_iterations + 1, 50000)])

plt.xlabel('Iteration (x10,000)',fontsize=14)
plt.ylabel('k Value',fontsize=14)
plt.legend(frameon=False,fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)  

##lr=1e-3
para1_history001_13=np.loadtxt(r"D:\new\code\2D\slum\metinverse\0.01\nondecay\param_record_30w_10_1e-3_nondecay-420-100.txt")
para2_history001_13=np.loadtxt(r"D:\new\code\2D\slum\metinverse\0.01\nondecay\param_record_30w_20_1e-3_nondecay-420-100.txt")
para3_history001_13=np.loadtxt(r"D:\new\code\2D\slum\metinverse\0.01\nondecay\param_record_30w_30_1e-3_nondecay-420-100.txt")
para4_history001_13=np.loadtxt(r"D:\new\code\2D\slum\metinverse\0.01\nondecay\param_record_30w_50_1e-3_nondecay-420-100.txt")

iterations = list(range(0, len(para1_history001_13) * 1000, 1000))
plt.figure(figsize=(6, 5))
plt.plot(iterations, para1_history001_13, label='ob_num=10', color='orange')
plt.plot(iterations, para2_history001_13, label='ob_num=20', color='b')
plt.plot(iterations, para3_history001_13, label='ob_num=30', color='y')
plt.plot(iterations, para4_history001_13, label='ob_num=50', color='purple')
plt.axhline(y=0.01, color='r', linestyle='--', label='True k = 0.01')  
max_iterations = max(iterations)

plt.xticks([i for i in range(0, max_iterations + 1, 50000)], 
           [str(i // 10000) for i in range(0, max_iterations + 1, 50000)])

plt.xlabel('Iteration (x10,000)',fontsize=14)
plt.ylabel('k Value',fontsize=14)
plt.legend(frameon=False,fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)

# %% [markdown]
# # MET_inverse_para_m

# %% [markdown]
# # m=1.05decay

# %%
para1_history_decay=np.loadtxt(r"D:\new\code\2D\slum\metinverse\1.05\decay\param_record_30w_10_5e-3_decay1000.txt")
para2_history_decay=np.loadtxt(r"D:\new\code\2D\slum\metinverse\1.05\decay\param_record_30w_20_5e-3_decay1000.txt")
para3_history_decay=np.loadtxt(r"D:\new\code\2D\slum\metinverse\1.05\decay\param_record_30w_30_5e-3_decay1000.txt")
para4_history_decay=np.loadtxt(r"D:\new\code\2D\slum\metinverse\1.05\decay\param_record_30w_50_5e-3_decay1000.txt")

iterations = list(range(0, len(para1_history_decay) * 1000, 1000))
plt.figure(figsize=(6, 5))
plt.plot(iterations, para1_history_decay, label='ob_num=10', color='orange')
plt.plot(iterations, para2_history_decay, label='ob_num=20', color='b')
plt.plot(iterations, para3_history_decay, label='ob_num=30', color='y')
plt.plot(iterations, para4_history_decay, label='ob_num=50', color='purple')
plt.axhline(y=1.05, color='r', linestyle='--', label='True m = 1.05')  
max_iterations = max(iterations)

plt.xticks([i for i in range(0, max_iterations + 1, 50000)], 
           [str(i // 10000) for i in range(0, max_iterations + 1, 50000)])

plt.xlabel('Iteration  (x10,000)',fontsize=14)
plt.ylabel('m Value',fontsize=14)
plt.legend(frameon=False,fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)

# %% [markdown]
# # m=1.05nondecay

# %%
##lr=5e-4
para1_history105_54=np.loadtxt(r"D:\new\code\2D\metinverse\1.05\nondecay\param_record_30w_10_5e-4_nodecay.txt")
para2_history105_54=np.loadtxt(r"D:\new\code\2D\slum\metinverse\1.05\nondecay\param_record_30w_20_5e-4_nodecay.txt")
para3_history105_54=np.loadtxt(r"D:\new\code\2D\metinverse\1.05\nondecay\param_record_30w_30_5e-4_nodecay.txt")
para4_history105_54=np.loadtxt(r"D:\new\code\2D\metinverse\1.05\nondecay\param_record_30w_50_5e-4_nodecay.txt")

iterations = list(range(0, len(para1_history_decay) * 1000, 1000))
plt.figure(figsize=(6, 5))
plt.plot(iterations, para1_history105_54, label='ob_num=10', color='orange')
plt.plot(iterations, para2_history105_54, label='ob_num=20', color='b')
plt.plot(iterations, para3_history105_54, label='ob_num=30', color='y')
plt.plot(iterations, para4_history105_54, label='ob_num=50', color='purple')
plt.axhline(y=1.05, color='r', linestyle='--', label='True m = 1.05')  # 真值
max_iterations = max(iterations)

plt.xticks([i for i in range(0, max_iterations + 1, 50000)], 
           [str(i // 10000) for i in range(0, max_iterations + 1, 50000)])

plt.xlabel('Iteration (x10,000)',fontsize=14)
plt.ylabel('m Value',fontsize=14)
plt.legend(frameon=False,fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)


##lr=1e-3
para1_history105_13=np.loadtxt(r"D:\new\code\2D\metinverse\1.05\nondecay\param_record_30w_10_1e-3_nodecay.txt")
para2_history105_13=np.loadtxt(r"D:\new\code\2D\metinverse\1.05\nondecay\param_record_30w_20_1e-3_nodecay.txt")
para3_history105_13=np.loadtxt(r"D:\new\code\2D\metinverse\1.05\nondecay\param_record_30w_30_1e-3_nodecay.txt")
para4_history105_13=np.loadtxt(r"D:\new\code\2D\metinverse\1.05\nondecay\param_record_30w_50_1e-3_nodecay.txt")

iterations = list(range(0, len(para1_history_decay) * 1000, 1000))
plt.figure(figsize=(6, 5))
plt.plot(iterations, para1_history105_13, label='ob_num=10', color='orange')
plt.plot(iterations, para2_history105_13, label='ob_num=20', color='b')
plt.plot(iterations, para3_history105_13, label='ob_num=30', color='y')
plt.plot(iterations, para4_history105_13, label='ob_num=50', color='purple')
plt.axhline(y=1.05, color='r', linestyle='--', label='True m = 1.05')  
max_iterations = max(iterations)

plt.xticks([i for i in range(0, max_iterations + 1, 50000)], 
           [str(i // 10000) for i in range(0, max_iterations + 1, 50000)])

plt.xlabel('Iteration (x10,000)',fontsize=14)
plt.ylabel('m Value',fontsize=14)
plt.legend(frameon=False,fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)

# %% [markdown]
# # EP_inverse_para_k

# %% [markdown]
# # k=0.01decay

# %%
para1_history001=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.01\decay\para0.01_record_30w_10_5e-3_decay1000.txt")
para2_history001=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.01\decay\para0.01_record_30w_20_5e-3_decay1000.txt")
para3_history001=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.01\decay\para0.01_record_30w_30_5e-3_decay1000.txt")
para4_history001=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.01\decay\para0.01_record_30w_50_5e-3_decay1000.txt")

iterations = list(range(0, len(para1_history001) * 1000, 1000))
plt.figure(figsize=(6, 5))
plt.plot(iterations, para1_history001, label='ob_num=10', color='orange')
plt.plot(iterations, para2_history001, label='ob_num=20', color='b')
plt.plot(iterations, para3_history001, label='ob_num=30', color='y')
plt.plot(iterations, para4_history001, label='ob_num=50', color='purple')
plt.axhline(y=0.01, color='r', linestyle='--', label='True k = 0.01')  
max_iterations = max(iterations)

plt.xticks([i for i in range(0, max_iterations + 1, 50000)], 
           [str(i // 10000) for i in range(0, max_iterations + 1, 50000)])

plt.xlabel('Iteration (x10,000)',fontsize=14)
plt.ylabel('k Value',fontsize=14)
plt.legend(frameon=False,fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)

# %% [markdown]
# # k=0.01nondecay

# %%
#lr=5e-4
para1_history001_54=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.01\nondecay\para0.01_record_30w_10_5e-4_nondecay-100.txt")
para2_history001_54=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.01\nondecay\para0.01_record_30w_20_5e-4_nondecay-100.txt")
para3_history001_54=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.01\nondecay\para0.01_record_30w_30_5e-4_nondecay-100.txt")
para4_history001_54=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.01\nondecay\para0.01_record_30w_50_5e-4_nondecay-100.txt")

iterations = list(range(0, len(para1_history001_54) * 1000, 1000))
plt.figure(figsize=(6, 5))
plt.plot(iterations, para1_history001_54, label='ob_num=10', color='orange')
plt.plot(iterations, para2_history001_54, label='ob_num=20', color='b')
plt.plot(iterations, para3_history001_54, label='ob_num=30', color='y')
plt.plot(iterations, para4_history001_54, label='ob_num=50', color='purple')
plt.axhline(y=0.01, color='r', linestyle='--', label='True k = 0.01')
max_iterations = max(iterations)

plt.xticks([i for i in range(0, max_iterations + 1, 50000)], 
           [str(i // 10000) for i in range(0, max_iterations + 1, 50000)])

plt.xlabel('Iteration (x10,000)',fontsize=14)
plt.ylabel('k Value',fontsize=14)
plt.legend(frameon=False,fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)


#lr=1e-3
para1_history001_13=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.01\nondecay\para0.01_record_30w_10_1e-3_nondecay-100.txt")
para2_history001_13=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.01\nondecay\para0.01_record_30w_20_1e-3_nondecay-100.txt")
para3_history001_13=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.01\nondecay\para0.01_record_30w_30_1e-3_nondecay-100.txt")
para4_history001_13=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.01\nondecay\para0.01_record_30w_50_1e-3_nondecay-100.txt")

iterations = list(range(0, len(para1_history001_13) * 1000, 1000))
plt.figure(figsize=(6, 5))
plt.plot(iterations, para1_history001_13, label='ob_num=10', color='orange')
plt.plot(iterations, para2_history001_13, label='ob_num=20', color='b')
plt.plot(iterations, para3_history001_13, label='ob_num=30', color='y')
plt.plot(iterations, para4_history001_13, label='ob_num=50', color='purple')
plt.axhline(y=0.01, color='r', linestyle='--', label='True k = 0.01') 
max_iterations = max(iterations)

plt.xticks([i for i in range(0, max_iterations + 1, 50000)], 
           [str(i // 10000) for i in range(0, max_iterations + 1, 50000)])


plt.xlabel('Iteration (x10,000)',fontsize=14)
plt.ylabel('k Value',fontsize=14)
plt.legend(frameon=False,fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)

# %% [markdown]
# # EP_inverse_para_p

# %% [markdown]
# # p=-1/3 decay

# %%
para1_history_decay=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.3\decay\para0.3_record_30w_10_5e-3_decay1000-432-100.txt")
para2_history_decay=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.3\decay\para0.3_record_30w_20_5e-3_decay1000-432-100.txt")
para3_history_decay=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.3\decay\para0.3_record_30w_30_5e-3_decay1000-432-100.txt")
para4_history_decay=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.3\decay\para0.3_record_30w_50_5e-3_decay1000-432-100.txt")

iterations = list(range(0, len(para1_history_decay) * 1000, 1000))
plt.figure(figsize=(6, 5))
plt.plot(iterations, para1_history_decay, label='ob_num=10', color='orange')
plt.plot(iterations, para2_history_decay, label='ob_num=20', color='b')
plt.plot(iterations, para3_history_decay, label='ob_num=30', color='y')
plt.plot(iterations, para4_history_decay, label='ob_num=50', color='purple')
plt.axhline(y=-1/3, color='r', linestyle='--', label='True p = -1/3')
max_iterations = max(iterations)

plt.xticks([i for i in range(0, max_iterations + 1, 50000)], 
           [str(i // 10000) for i in range(0, max_iterations + 1, 50000)])
plt.xlabel('Iteration (x10,000)',fontsize=14)
plt.ylabel('p Value',fontsize=14)
plt.legend(frameon=False,fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)

# %% [markdown]
# # p=-1/3 nondecay

# %%
#lr=5e-4
para1_history105_54=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.3\nondecay\para0.3_record_30w_10_5e-4-100.txt")
para2_history105_54=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.3\nondecay\para0.3_record_30w_20_5e-4-100.txt")
para3_history105_54=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.3\nondecay\para0.3_record_30w_30_5e-4-100.txt")
para4_history105_54=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.3\nondecay\para0.3_record_30w_50_5e-4-100.txt")

iterations = list(range(0, len(para1_history105_54) * 1000, 1000))
plt.figure(figsize=(6, 5))
plt.plot(iterations, para1_history105_54, label='ob_num=10', color='orange')
plt.plot(iterations, para2_history105_54, label='ob_num=20', color='b')
plt.plot(iterations, para3_history105_54, label='ob_num=30', color='y')
plt.plot(iterations, para4_history105_54, label='ob_num=50', color='purple')
plt.axhline(y=-1/3, color='r', linestyle='--', label='True p = -1/3') 
max_iterations = max(iterations)

plt.xticks([i for i in range(0, max_iterations + 1, 50000)], 
           [str(i // 10000) for i in range(0, max_iterations + 1, 50000)])

plt.xlabel('Iteration (x10,000)',fontsize=14)
plt.ylabel('p Value',fontsize=14)
plt.legend(frameon=False,fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)


#lr=1e-3
para1_history105_13=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.3\nondecay\para0.3_record_30w_10_1e-3-100.txt")
para2_history105_13=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.3\nondecay\para0.3_record_30w_20_1e-3-100.txt")
para3_history105_13=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.3\nondecay\para0.3_record_30w_30_1e-3-100.txt")
para4_history105_13=np.loadtxt(r"D:\new\code\2D\slum\epinv\0.3\nondecay\para0.3_record_30w_50_1e-3-100.txt")

iterations = list(range(0, len(para1_history105_13) * 1000, 1000))
plt.figure(figsize=(6, 5))
plt.plot(iterations, para1_history105_13, label='ob_num=10', color='orange')
plt.plot(iterations, para2_history105_13, label='ob_num=20', color='b')
plt.plot(iterations, para3_history105_13, label='ob_num=30', color='y')
plt.plot(iterations, para4_history105_13, label='ob_num=50', color='purple')
plt.axhline(y=-1/3, color='r', linestyle='--', label='True p = -1/3') 
max_iterations = max(iterations)


plt.xticks([i for i in range(0, max_iterations + 1, 50000)], 
           [str(i // 10000) for i in range(0, max_iterations + 1, 50000)])

plt.xlabel('Iteration (x10,000)',fontsize=14)
plt.ylabel('p Value',fontsize=14)
plt.legend(frameon=False,fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)
